# %%
using NumericalEarth
using Oceananigans
using Oceananigans.Units
using Oceananigans.Grids: node
using Oceananigans.TurbulenceClosures:
    IsopycnalSkewSymmetricDiffusivity,
    AdvectiveFormulation
using Dates
using Printf
using CUDA

# %%
# determining run version/params - :validation, :spinup, or :production
run_mode = :validation

@assert run_mode in (:validation, :spinup, :production)

validation_days = 80
spinup_days = 365
production_days = 80

use_rivers = true

# start at 90 seconds; TimeStepWizard may decrease or increase this
initial_time_step = 90seconds

# maximum timestep allowed by TimeStepWizard
maximum_time_step = 180seconds

resolution_tag = "FINAL_nz20_gm_off_redi_off_salinity_80day_v2"

if use_rivers
    run_name = "rivers_on"
else
    run_name = "rivers_off"
end

if run_mode == :validation
    output_tag = "$(run_name)_validation_$(resolution_tag)"
elseif run_mode == :spinup
    output_tag = "$(run_name)_spinup_$(resolution_tag)"
elseif run_mode == :production
    output_tag = "$(run_name)_production_$(resolution_tag)"
end

surface_filename = "amazon_$(output_tag)_surface_fields"
free_surface_filename = "amazon_$(output_tag)_free_surface"
dye_3d_filename = "amazon_$(output_tag)_dye_3d"
salinity_3d_filename = "amazon_$(output_tag)_salinity_3d"

checkpoint_prefix = "amazon_$(run_name)_$(resolution_tag)_$(run_mode)_checkpoint"

production_initial_checkpoint = "amazon_$(run_name)_$(resolution_tag)_day365_with_dye.jld2"
# Out:
# "amazon_rivers_on_FINAL_nz20_gm_off_redi_off_salinity_80day_v2_day365_with_dye.jld2"

# %%
arch = GPU()

# grid definitions -- amazon river mouth / plume region
long_west = -58.5
long_east = -41.5
lat_south = -7.8
lat_north = 9.2

Nx = 340
Ny = 340
Nz = 20

long_river = -49.5
lat_river = 0.16

depth = 4000meters

longitude_resolution = (long_east - long_west) / Nx
latitude_resolution = (lat_north - lat_south) / Ny

@assert longitude_resolution ≈ 0.05
@assert latitude_resolution ≈ 0.05

z = ExponentialDiscretization(
    Nz,
    -depth,
    0;
    scale = depth / 4,
    mutable = false
)

underlying_grid = LatitudeLongitudeGrid(
    arch;
    size = (Nx, Ny, Nz),
    halo = (5, 5, 4),
    longitude = (long_west, long_east),
    latitude = (lat_south, lat_north),
    z,
    topology = (Bounded, Bounded, Bounded)
)

# use at least 30 m so river-mouth columns can mix below the surface cell
bottom_height = regrid_bathymetry(
    underlying_grid;
    minimum_depth = 30,
    interpolation_passes = 10,
    major_basins = 1
)

grid = ImmersedBoundaryGrid(
    underlying_grid,
    GridFittedBottom(bottom_height);
    active_cells_map = true
)
# Out:
# [ Info: Loading cached bathymetry from C:\Users\meghn\.julia\scratchspaces\904d977b-046a-4731-8b86-9235c0d1ef02\bathymetry_cache\bathymetry_340x340_-58.5_-41.5_-7.799999999999999_9.2_51edf445.jld2
# 340×340×20 ImmersedBoundaryGrid{Float64, Bounded, Bounded, Bounded} on CUDAGPU with 5×5×4 halo:
# ├── immersed_boundary: GridFittedBottom(mean(z)=-1077.73, min(z)=-4000.0, max(z)=0.0)
# ├── underlying_grid: 340×340×20 LatitudeLongitudeGrid{Float64, Bounded, Bounded, Bounded} on CUDAGPU with 5×5×4 halo
# ├── longitude: Bounded  λ ∈ [-58.5, -41.5] regularly spaced with Δλ=0.05
# ├── latitude:  Bounded  φ ∈ [-7.8, 9.2]    regularly spaced with Δφ=0.05
# └── z:         Bounded  z ∈ [-4000.0, 0.0] variably spaced with min(Δz)=16.5232, max(Δz)=738.605

# %%
# Gent–McWilliams remains on.
# Redi symmetric diffusion is zero for every tracer.
const gm_skew_diffusivity = 1e3
const redi_diffusivity = 0.0

eddy_closure = IsopycnalSkewSymmetricDiffusivity(
    κ_skew = gm_skew_diffusivity,
    κ_symmetric = (
        T = redi_diffusivity,
        S = redi_diffusivity,
        dye = redi_diffusivity,
        e = redi_diffusivity
    ),
    skew_flux_formulation = AdvectiveFormulation()
)

# default NumericalEarth vertical mixing
vertical_mixing = NumericalEarth.Oceans.default_ocean_closure()

# Trial 4.10 additional vertical tracer mixing near the river mouth
const river_mixing_longitude = -49.35
const river_mixing_latitude = -0.15
const river_mixing_kz = 1e-3
const river_mixing_depth = 30meters
const river_mixing_half_width = 0.75

@inline function river_mouth_kz(longitude, latitude, z, time)
    inside_longitude = abs(longitude - river_mixing_longitude) <= river_mixing_half_width
    inside_latitude = abs(latitude - river_mixing_latitude) <= river_mixing_half_width
    inside_depth = z >= -river_mixing_depth

    if inside_longitude && inside_latitude && inside_depth
        return river_mixing_kz
    else
        return 0.0
    end
end

river_mixing = VerticalScalarDiffusivity(
    VerticallyImplicitTimeDiscretization();
    κ = (
        T = river_mouth_kz,
        S = river_mouth_kz,
        dye = river_mouth_kz,
        e = 0.0
    )
)

closure = (
    vertical_mixing,
    river_mixing
)

@assert gm_skew_diffusivity == 1e3
@assert redi_diffusivity == 0.0

@assert river_mouth_kz(
    river_mixing_longitude,
    river_mixing_latitude,
    -10,
    0
) == river_mixing_kz

@assert river_mouth_kz(
    river_mixing_longitude,
    river_mixing_latitude,
    -40,
    0
) == 0.0

# %%
free_surface = SplitExplicitFreeSurface(
    grid;
    substeps = 140
)

momentum_advection = WENOVectorInvariant(order = 5)

# preserve Trial 4.10 tracer advection
tracer_advection = (
    T = WENO(order = 5),
    S = WENO(order = 5),
    dye = UpwindBiased(order = 1)
)

# create zero-gradient boundary conditions for dye
dye_bcs = FieldBoundaryConditions(
    west = GradientBoundaryCondition(0),
    east = GradientBoundaryCondition(0),
    south = GradientBoundaryCondition(0),
    north = GradientBoundaryCondition(0),
    top = FluxBoundaryCondition(0),
    bottom = FluxBoundaryCondition(0)
)

model_bcs = (
    dye = dye_bcs,
)

# these values must be constant because the sponge runs on the GPU
const north_sponge_mask = GaussianMask{:y}(
    center = 9.2,
    width = 0.25
)

const north_sponge_rate = 1 / 5days

@inline function north_dye_sponge(i, j, k, grid, clock, model_fields)
    x, y, z = node(
        i,
        j,
        k,
        grid,
        Center(),
        Center(),
        Center()
    )

    mask = north_sponge_mask(x, y, z)

    dye = @inbounds model_fields.dye[i, j, k]

    return -north_sponge_rate * mask * dye
end

dye_sponge = Forcing(
    north_dye_sponge;
    discrete_form = true
)

model_forcing = (
    dye = dye_sponge,
)

ocean = ocean_simulation(
    grid;
    momentum_advection,
    tracer_advection,
    free_surface,
    closure = closure,
    tracers = (:T, :S, :dye),
    boundary_conditions = model_bcs,
    forcing = model_forcing
)

@show ocean.model.closure
# Out:
# ocean.model.closure = (CATKEVerticalDiffusivity{VerticallyImplicitTimeDiscretization}
# ├── maximum_tracer_diffusivity: Inf
# ├── maximum_tke_diffusivity: Inf
# ├── maximum_viscosity: Inf
# ├── minimum_tke: 1.0e-9
# ├── negative_tke_time_scale: 60.0
# ├── minimum_convective_buoyancy_flux: 1.0e-11
# ├── tke_time_step: Nothing
# ├── mixing_length: TKEBasedVerticalDiffusivities.CATKEMixingLength
# │   ├── Cˢ:   1.131
# │   ├── Cᵇ:   0.01
# │   ├── Cʰⁱu: 0.242
# │   ├── Cʰⁱc: 0.098
# │   ├── Cʰⁱe: 0.548
# │   ├── Cˡᵒu: 0.361
# │   ├── Cˡᵒc: 0.369
# │   ├── Cˡᵒe: 7.863
# │   ├── Cᵘⁿu: 0.37
# │   ├── Cᵘⁿc: 0.572
# │   ├── Cᵘⁿe: 1.447
# │   ├── Cᶜu:  3.705
# │   ├── Cᶜc:  4.793
# │   ├── Cᶜe:  3.642
# │   ├── Cᵉc:  0.112
# │   ├── Cᵉe:  0.0
# │   ├── Cˢᵖ:  0.505
# │   ├── CRiᵟ: 1.02
# │   └── CRi⁰: 0.254
# └── turbulent_kinetic_energy_equation: TKEBasedVerticalDiffusivities.CATKEEquation
#     ├── CʰⁱD: 0.579
#     ├── CˡᵒD: 1.604
#     ├── CᵘⁿD: 0.923
#     ├── CᶜD:  3.254
#     ├── CᵉD:  0.0
#     ├── Cᵂu★: 3.179
#     ├── CᵂwΔ: 0.383
#     └── Cᵂϵ:  1.0, VerticalScalarDiffusivity{VerticallyImplicitTimeDiscretization}(ν=0.0, κ=(T=river_mouth_kz (generic function with 1 method), S=river_mouth_kz (generic function with 1 method), dye=river_mouth_kz (generic function with 1 method), e=0.0)))
# (CATKEVerticalDiffusivity{VerticallyImplicitTimeDiscretization}
# ├── maximum_tracer_diffusivity: Inf
# ├── maximum_tke_diffusivity: Inf
# ├── maximum_viscosity: Inf
# ├── minimum_tke: 1.0e-9
# ├── negative_tke_time_scale: 60.0
# ├── minimum_convective_buoyancy_flux: 1.0e-11
# ├── tke_time_step: Nothing
# ├── mixing_length: TKEBasedVerticalDiffusivities.CATKEMixingLength
# │   ├── Cˢ:   1.131
# │   ├── Cᵇ:   0.01
# │   ├── Cʰⁱu: 0.242
# │   ├── Cʰⁱc: 0.098
# │   ├── Cʰⁱe: 0.548
# │   ├── Cˡᵒu: 0.361
# │   ├── Cˡᵒc: 0.369
# │   ├── Cˡᵒe: 7.863
# │   ├── Cᵘⁿu: 0.37
# │   ├── Cᵘⁿc: 0.572
# │   ├── Cᵘⁿe: 1.447
# │   ├── Cᶜu:  3.705
# │   ├── Cᶜc:  4.793
# │   ├── Cᶜe:  3.642
# │   ├── Cᵉc:  0.112
# │   ├── Cᵉe:  0.0
# │   ├── Cˢᵖ:  0.505
# │   ├── CRiᵟ: 1.02
# │   └── CRi⁰: 0.254
# └── turbulent_kinetic_energy_equation: TKEBasedVerticalDiffusivities.CATKEEquation
#     ├── CʰⁱD: 0.579
#     ├── CˡᵒD: 1.604
#     ├── CᵘⁿD: 0.923
#     ├── CᶜD:  3.254
#     ├── CᵉD:  0.0
#     ├── Cᵂu★: 3.179
#     ├── CᵂwΔ: 0.383
#     └── Cᵂϵ:  1.0, VerticalScalarDiffusivity{VerticallyImplicitTimeDiscretization}(ν=0.0, κ=(T=river_mouth_kz (generic function with 1 method), S=river_mouth_kz (generic function with 1 method), dye=river_mouth_kz (generic function with 1 method), e=0.0)))

# %%
@inline function dye_initial_condition(x, y, z)
    horizontal_width = 0.5

    horizontal_blob = exp(
        -(
            (x - long_river)^2 +
            (y - lat_river)^2
        ) / horizontal_width^2
    )

    if z > -10
        return horizontal_blob
    else
        return 0.0
    end
end

# validation and spinup are fresh runs initialized from ECCO
if run_mode == :validation || run_mode == :spinup
    ENV["ECCO_USERNAME"] = "meggoeggo"
    ENV["ECCO_WEBDAV_PASSWORD"] = "3a0bqyAsTojLw4ZtpKaC"


    date = DateTime(1993, 1, 1)

    ecco_variables = (
        :temperature,
        :salinity
    )

    ecco_set = MetadataSet(
        ecco_variables;
        dataset = ECCO4Monthly(),
        date
    )

    set!(ocean.model, ecco_set)
end

land = JRA55PrescribedLand(arch)

atmosphere = JRA55PrescribedAtmosphere(arch)

ocean_surface = SurfaceRadiationProperties(
    albedo = LatitudeDependentAlbedo()
)

radiation = JRA55PrescribedRadiation(
    arch;
    ocean_surface
)

@assert use_rivers "The final model requires the original JRA55 river forcing"

coupled_model = EarthSystemModel(
    ;
    ocean,
    atmosphere,
    land,
    radiation
)

if run_mode == :validation
    stop_day = validation_days
elseif run_mode == :spinup
    stop_day = spinup_days
elseif run_mode == :production
    # production begins at day 365 and runs for another 180 days
    stop_day = spinup_days + production_days
end

simulation = Simulation(
    coupled_model;
    Δt = initial_time_step,
    stop_time = stop_day * days
)

# TimeStepWizard is attached to the coupled EarthSystemModel.
# Calculate its advective timescale from the ocean component.
function ocean_advection_timescale(earth_system)
    return Oceananigans.Advection.cell_advection_timescale(
        earth_system.ocean.model
    )
end

time_step_wizard = TimeStepWizard(
    cfl = 0.5,
    max_change = 1.05,
    min_change = 0.2,
    max_Δt = maximum_time_step, 
    min_Δt = 1.0,
    cell_advection_timescale = ocean_advection_timescale
)

simulation.callbacks[:time_step_wizard] = Callback(
    time_step_wizard,
    IterationInterval(5)
)
# Out:
# ┌ Warning: 1440×720×1×365 PrescribedLand tracks time as Float32 but the EarthSystemModel clock uses Float64; coercing the component clock to keep components synchronized.
# └ @ NumericalEarth.EarthSystemModels C:\Users\meghn\.julia\packages\NumericalEarth\eKhWQ\src\EarthSystemModels\components.jl:136
# Callback of TimeStepWizard(cfl=0.5, max_Δt=180.0, min_Δt=1.0) on IterationInterval(5)

# %%
wall_time = Ref(time_ns())

function progress(sim)
    ocean = sim.model.ocean

    u, v, w = ocean.model.velocities

    T = ocean.model.tracers.T
    S = ocean.model.tracers.S
    dye = ocean.model.tracers.dye
    e = ocean.model.tracers.e

    Tmin, Tmax = minimum(T), maximum(T)
    Smin, Smax = minimum(S), maximum(S)
    dyemin, dyemax = minimum(dye), maximum(dye)
    emin, emax = minimum(e), maximum(e)

    umax = (
        maximum(abs, u),
        maximum(abs, v),
        maximum(abs, w)
    )

    current_Δt = sim.Δt

    cfl = AdvectiveCFL(current_Δt)(
        ocean.model
    )

    step_time = 1e-9 * (
        time_ns() - wall_time[]
    )

    msg1 = @sprintf(
        "time: %s, iter: %d, Δt: %s",
        prettytime(sim),
        iteration(sim),
        prettytime(current_Δt)
    )

    msg2 = @sprintf(
        ", max|u|: (%.3e, %.3e, %.3e) m s⁻¹",
        umax[1],
        umax[2],
        umax[3]
    )

    msg3 = @sprintf(
        "\nT:    min = %.6e, max = %.6e °C",
        Tmin,
        Tmax
    )

    msg4 = @sprintf(
        "\nS:    min = %.6e, max = %.6e",
        Smin,
        Smax
    )

    msg5 = @sprintf(
        "\ndye:  min = %.6e, max = %.6e",
        dyemin,
        dyemax
    )

    msg6 = @sprintf(
        "\ne:    min = %.6e, max = %.6e m² s⁻²",
        emin,
        emax
    )

    msg7 = @sprintf(
        "\nadvective CFL = %.6e",
        cfl
    )

    msg8 = @sprintf(
        "\nwall time since last report: %s\n",
        prettytime(step_time)
    )

    @info msg1 * msg2 * msg3 * msg4 * msg5 * msg6 * msg7 * msg8

    if dyemin < 0
        warning_message = @sprintf(
            "NEGATIVE DYE DETECTED: min(dye) = %.6e",
            dyemin
        )

        @warn warning_message
    end

    if dyemax > 1
        warning_message = @sprintf(
            "DYE OVERSHOOT DETECTED: max(dye) = %.6e",
            dyemax
        )

        @warn warning_message
    end

    if Smin < 0
        warning_message = @sprintf(
            "NEGATIVE SALINITY DETECTED: min(S) = %.6e",
            Smin
        )

        @warn warning_message
    end

    if cfl > 0.8
        warning_message = @sprintf(
            "ADVECTIVE CFL ABOVE 0.8: CFL = %.6e",
            cfl
        )

        @warn warning_message
    end

    wall_time[] = time_ns()

    return nothing
end

add_callback!(
    simulation,
    progress,
    TimeInterval(1days)
)

# %%
# collect surface tracers and velocities
ocean_outputs = merge(
    ocean.model.tracers,
    ocean.model.velocities
)

# grab the free-surface displacement
free_surface = ocean.model.free_surface.displacement

# save daily surface tracers and velocities
ocean.output_writers[:surface] = JLD2Writer(
    ocean.model,
    ocean_outputs;
    schedule = TimeInterval(1days),
    filename = surface_filename,
    indices = (:, :, grid.Nz),
    overwrite_existing = true
)

# save daily sea-surface height
ocean.output_writers[:free_surface] = JLD2Writer(
    ocean.model,
    (
        η = free_surface,
    );
    schedule = TimeInterval(1days),
    filename = free_surface_filename,
    overwrite_existing = true
)

if run_mode == :validation
    salinity_output_interval = 1days
elseif run_mode == :spinup
    salinity_output_interval = 30days
elseif run_mode == :production
    salinity_output_interval = 5days
end

ocean.output_writers[:salinity_3d] = JLD2Writer(
    ocean.model,
    (
        S = ocean.model.tracers.S,
    );
    schedule = TimeInterval(salinity_output_interval),
    filename = salinity_3d_filename,
    overwrite_existing = true
)

if run_mode == :validation || run_mode == :production
    ocean.output_writers[:dye_3d] = JLD2Writer(
        ocean.model,
        (
            dye = ocean.model.tracers.dye,
        );
        schedule = TimeInterval(1days),
        filename = dye_3d_filename,
        overwrite_existing = true
    )
end

if run_mode == :spinup || run_mode == :production
    simulation.output_writers[:checkpointer] = Checkpointer(
        simulation.model;
        schedule = TimeInterval(30days),
        prefix = checkpoint_prefix,
        cleanup = true,
        overwrite_existing = true
    )
end

# %%
@assert iteration(simulation) == 0 "Restart the kernel and rebuild the simulation before starting a run"

if run_mode == :validation
    set!(
    ocean.model,
    dye = dye_initial_condition
    )

    @info "Starting 60-day salinity validation"

    progress(simulation)

    run!(simulation)

    validation_Smin = minimum(
        ocean.model.tracers.S
    )

    validation_Smax = maximum(
        ocean.model.tracers.S
    )

    validation_Δt = simulation.Δt

    validation_CFL = AdvectiveCFL(
        validation_Δt
    )(
        ocean.model
    )

    @info(
        "60-day validation complete",
        validation_Smin,
        validation_Smax,
        validation_CFL,
        validation_Δt
    )

    if validation_Smin < 0
        error(
            "Validation failed: negative salinity = $validation_Smin"
        )
    end

    if validation_CFL > 0.8
        error(
            "Validation failed: final advective CFL = $validation_CFL"
        )
    end

elseif run_mode == :spinup
    # spinup begins from ECCO with no dye
    set!(
        ocean.model,
        dye = 0.0
    )

    @assert !isfile(
        production_initial_checkpoint
    ) "Move or rename the existing production checkpoint before starting a new spinup"

    @info "Starting fresh 365-day spinup"

    progress(simulation)

    run!(
        simulation;
        checkpoint_at_end = true
    )

    spinup_Smin = minimum(
        ocean.model.tracers.S
    )

    spinup_Smax = maximum(
        ocean.model.tracers.S
    )

    @info(
        "365-day spinup complete",
        spinup_Smin,
        spinup_Smax,
        final_Δt = simulation.Δt
    )

    if spinup_Smin < 0
        error(
            "Spinup produced negative salinity: $spinup_Smin"
        )
    end

    # deposit dye only after spinup
    set!(
        ocean.model,
        dye = dye_initial_condition
    )

    minimum_dye = minimum(
        ocean.model.tracers.dye
    )

    maximum_dye = maximum(
        ocean.model.tracers.dye
    )

    @info(
        "Dye deposited after spinup",
        minimum_dye,
        maximum_dye
    )

    # save the spun-up state with newly deposited dye
    checkpoint(
        simulation;
        filepath = production_initial_checkpoint
    )

    @info(
        "Production checkpoint written",
        production_initial_checkpoint
    )

elseif run_mode == :production
    @assert isfile(
        production_initial_checkpoint
    ) "Run the 365-day spinup first; production checkpoint is missing"

    @info(
        "Starting 180-day dye production run",
        production_initial_checkpoint
    )

    # pickup restores the day-365 clock and dye state
    # the simulation stops at absolute model day 545
    run!(
        simulation;
        pickup = production_initial_checkpoint,
        checkpoint_at_end = true
    )
end
# Out:
# [ Info: Starting 60-day salinity validation
# ┌ Info: time: 0 seconds, iter: 0, Δt: 1.500 minutes, max|u|: (0.000e+00, 0.000e+00, 0.000e+00) m s⁻¹
# │ T:    min = 2.119263e+00, max = 2.817149e+01 °C
# │ S:    min = 3.102885e+01, max = 3.669934e+01
# │ dye:  min = 0.000000e+00, max = 9.966058e-01
# │ e:    min = 0.000000e+00, max = 0.000000e+00 m² s⁻²
# │ advective CFL = 0.000000e+00
# └ wall time since last report: 1.699 minutes
# [ Info: Initializing simulation...
# ┌ Info: time: 0 seconds, iter: 0, Δt: 1.575 minutes, max|u|: (0.000e+00, 0.000e+00, 0.000e+00) m s⁻¹
# │ T:    min = 2.119263e+00, max = 2.817149e+01 °C
# │ S:    min = 3.102885e+01, max = 3.669934e+01
# │ dye:  min = 0.000000e+00, max = 9.966058e-01
# │ e:    min = 0.000000e+00, max = 0.000000e+00 m² s⁻²
# │ advective CFL = 0.000000e+00
# └ wall time since last report: 25.127 seconds
# [ Info:     ... simulation initialization complete (4.594 seconds)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (4.444 minutes).
# ┌ Info: time: 1 day, iter: 499, Δt: 3 minutes, max|u|: (4.232e-01, 2.789e-01, 3.034e-03) m s⁻¹
# │ T:    min = 2.117929e+00, max = 2.842692e+01 °C
# │ S:    min = 2.261542e+01, max = 3.855315e+01
# │ dye:  min = 8.395461e-301, max = 7.726015e-01
# │ e:    min = 3.737895e-16, max = 6.532629e-04 m² s⁻²
# │ advective CFL = 1.903048e-02
# └ wall time since last report: 9.622 minutes
# ┌ Info: time: 2 days, iter: 979, Δt: 3 minutes, max|u|: (5.463e-01, 4.263e-01, 3.270e-03) m s⁻¹
# │ T:    min = 2.108566e+00, max = 2.857314e+01 °C
# │ S:    min = 1.950635e+01, max = 4.031006e+01
# │ dye:  min = 4.338481e-267, max = 5.929602e-01
# │ e:    min = 3.392250e-15, max = 5.214050e-04 m² s⁻²
# │ advective CFL = 2.258566e-02
# └ wall time since last report: 5.086 minutes
# ┌ Info: time: 3 days, iter: 1459, Δt: 3 minutes, max|u|: (7.617e-01, 5.096e-01, 3.220e-03) m s⁻¹
# │ T:    min = 2.109917e+00, max = 2.874399e+01 °C
# │ S:    min = 1.831234e+01, max = 4.085724e+01
# │ dye:  min = 1.627835e-239, max = 5.197177e-01
# │ e:    min = 2.050316e-14, max = 5.118220e-04 m² s⁻²
# │ advective CFL = 2.707916e-02
# └ wall time since last report: 5.200 minutes
# ┌ Info: time: 4 days, iter: 1939, Δt: 3 minutes, max|u|: (7.772e-01, 6.201e-01, 5.913e-03) m s⁻¹
# │ T:    min = 2.097790e+00, max = 2.893511e+01 °C
# │ S:    min = 1.764602e+01, max = 4.082687e+01
# │ dye:  min = 3.076348e-229, max = 4.687389e-01
# │ e:    min = 5.028151e-14, max = 6.736030e-04 m² s⁻²
# │ advective CFL = 2.656371e-02
# └ wall time since last report: 5.147 minutes
# ┌ Info: time: 5 days, iter: 2419, Δt: 3 minutes, max|u|: (8.265e-01, 6.558e-01, 4.461e-03) m s⁻¹
# │ T:    min = 2.113095e+00, max = 2.906936e+01 °C
# │ S:    min = 1.727267e+01, max = 4.076449e+01
# │ dye:  min = 9.172566e-212, max = 4.492492e-01
# │ e:    min = 5.294381e-14, max = 6.374351e-04 m² s⁻²
# │ advective CFL = 2.885416e-02
# └ wall time since last report: 5.211 minutes
# ┌ Info: time: 6 days, iter: 2899, Δt: 3 minutes, max|u|: (7.676e-01, 6.864e-01, 2.510e-03) m s⁻¹
# │ T:    min = 2.109268e+00, max = 2.915680e+01 °C
# │ S:    min = 1.715110e+01, max = 4.068290e+01
# │ dye:  min = 2.893305e-187, max = 4.379023e-01
# │ e:    min = 4.819003e-14, max = 6.971729e-04 m² s⁻²
# │ advective CFL = 3.138529e-02
# └ wall time since last report: 5.218 minutes
# ┌ Info: time: 7 days, iter: 3379, Δt: 3 minutes, max|u|: (8.253e-01, 6.374e-01, 2.920e-03) m s⁻¹
# │ T:    min = 2.106171e+00, max = 2.932524e+01 °C
# │ S:    min = 1.706694e+01, max = 4.064328e+01
# │ dye:  min = 8.401210e-185, max = 4.278413e-01
# │ e:    min = 4.314962e-14, max = 6.177109e-04 m² s⁻²
# │ advective CFL = 2.973155e-02
# └ wall time since last report: 5.161 minutes
# ┌ Info: time: 8 days, iter: 3859, Δt: 3 minutes, max|u|: (8.899e-01, 5.277e-01, 6.641e-03) m s⁻¹
# │ T:    min = 2.101896e+00, max = 2.936343e+01 °C
# │ S:    min = 1.704224e+01, max = 4.074425e+01
# │ dye:  min = 3.382400e-184, max = 4.219900e-01
# │ e:    min = 4.974540e-14, max = 5.615445e-04 m² s⁻²
# │ advective CFL = 3.176269e-02
# └ wall time since last report: 5.212 minutes
# ┌ Info: time: 9 days, iter: 4339, Δt: 3 minutes, max|u|: (8.336e-01, 5.375e-01, 6.796e-03) m s⁻¹
# │ T:    min = 2.095087e+00, max = 2.946856e+01 °C
# │ S:    min = 1.689984e+01, max = 4.069622e+01
# │ dye:  min = 1.324529e-182, max = 4.159583e-01
# │ e:    min = 1.250741e-13, max = 6.743733e-04 m² s⁻²
# │ advective CFL = 3.318931e-02
# └ wall time since last report: 5.177 minutes
# ┌ Info: time: 10 days, iter: 4819, Δt: 3 minutes, max|u|: (8.422e-01, 5.482e-01, 9.805e-03) m s⁻¹
# │ T:    min = 2.100901e+00, max = 2.964173e+01 °C
# │ S:    min = 1.691059e+01, max = 4.069630e+01
# │ dye:  min = 1.216640e-177, max = 4.069846e-01
# │ e:    min = 1.179934e-13, max = 5.929146e-04 m² s⁻²
# │ advective CFL = 3.198269e-02
# └ wall time since last report: 5.225 minutes
# ┌ Info: time: 11 days, iter: 5299, Δt: 3 minutes, max|u|: (7.716e-01, 6.896e-01, 9.058e-03) m s⁻¹
# │ T:    min = 2.095004e+00, max = 2.985679e+01 °C
# │ S:    min = 1.676798e+01, max = 4.064119e+01
# │ dye:  min = 7.233786e-175, max = 3.997989e-01
# │ e:    min = 1.348076e-13, max = 8.001403e-04 m² s⁻²
# │ advective CFL = 3.521221e-02
# └ wall time since last report: 5.215 minutes
# ┌ Info: time: 12 days, iter: 5779, Δt: 3 minutes, max|u|: (7.101e-01, 6.371e-01, 9.946e-03) m s⁻¹
# │ T:    min = 2.087242e+00, max = 3.002447e+01 °C
# │ S:    min = 1.652742e+01, max = 4.045063e+01
# │ dye:  min = 2.301575e-173, max = 3.950736e-01
# │ e:    min = 1.417452e-13, max = 8.884001e-04 m² s⁻²
# │ advective CFL = 3.032619e-02
# └ wall time since last report: 5.131 minutes
# ┌ Info: time: 13 days, iter: 6259, Δt: 3 minutes, max|u|: (7.682e-01, 6.020e-01, 8.602e-03) m s⁻¹
# │ T:    min = 2.092082e+00, max = 3.002758e+01 °C
# │ S:    min = 1.633917e+01, max = 4.018594e+01
# │ dye:  min = 7.094461e-164, max = 3.827226e-01
# │ e:    min = 1.285214e-13, max = 7.678929e-04 m² s⁻²
# │ advective CFL = 3.030836e-02
# └ wall time since last report: 5.241 minutes
# ┌ Info: time: 14 days, iter: 6739, Δt: 3 minutes, max|u|: (7.094e-01, 7.646e-01, 4.126e-03) m s⁻¹
# │ T:    min = 2.086428e+00, max = 3.010224e+01 °C
# │ S:    min = 1.623985e+01, max = 3.994153e+01
# │ dye:  min = 2.943411e-163, max = 3.550281e-01
# │ e:    min = 1.258187e-13, max = 8.709580e-04 m² s⁻²
# │ advective CFL = 3.404908e-02
# └ wall time since last report: 5.227 minutes
# ┌ Info: time: 15 days, iter: 7219, Δt: 3 minutes, max|u|: (7.144e-01, 8.166e-01, 7.258e-03) m s⁻¹
# │ T:    min = 2.091233e+00, max = 3.012649e+01 °C
# │ S:    min = 1.609987e+01, max = 3.953116e+01
# │ dye:  min = 5.397041e-161, max = 3.435936e-01
# │ e:    min = 1.243407e-13, max = 9.615126e-04 m² s⁻²
# │ advective CFL = 3.107249e-02
# └ wall time since last report: 5.207 minutes
# ┌ Info: time: 16 days, iter: 7699, Δt: 3 minutes, max|u|: (7.154e-01, 7.332e-01, 3.406e-03) m s⁻¹
# │ T:    min = 2.073303e+00, max = 3.022050e+01 °C
# │ S:    min = 1.612471e+01, max = 3.920731e+01
# │ dye:  min = 2.468766e-156, max = 3.319212e-01
# │ e:    min = 1.284410e-13, max = 6.914907e-04 m² s⁻²
# │ advective CFL = 3.049604e-02
# └ wall time since last report: 5.173 minutes
# ┌ Info: time: 17 days, iter: 8179, Δt: 3 minutes, max|u|: (7.221e-01, 7.423e-01, 3.207e-03) m s⁻¹
# │ T:    min = 2.070485e+00, max = 3.023703e+01 °C
# │ S:    min = 1.594263e+01, max = 3.901245e+01
# │ dye:  min = 4.154989e-151, max = 3.241310e-01
# │ e:    min = 1.603718e-13, max = 8.032331e-04 m² s⁻²
# │ advective CFL = 3.241958e-02
# └ wall time since last report: 5.220 minutes
# ┌ Info: time: 18 days, iter: 8659, Δt: 3 minutes, max|u|: (7.565e-01, 8.800e-01, 2.416e-03) m s⁻¹
# │ T:    min = 2.076069e+00, max = 3.013411e+01 °C
# │ S:    min = 1.595415e+01, max = 3.918146e+01
# │ dye:  min = 2.068788e-148, max = 3.103321e-01
# │ e:    min = 1.853687e-13, max = 9.561703e-04 m² s⁻²
# │ advective CFL = 3.365533e-02
# └ wall time since last report: 5.226 minutes
# ┌ Info: time: 19 days, iter: 9139, Δt: 3 minutes, max|u|: (6.581e-01, 9.906e-01, 2.741e-03) m s⁻¹
# │ T:    min = 2.077778e+00, max = 3.006911e+01 °C
# │ S:    min = 1.600860e+01, max = 3.937091e+01
# │ dye:  min = 5.579896e-146, max = 2.811431e-01
# │ e:    min = 2.072744e-13, max = 7.548379e-04 m² s⁻²
# │ advective CFL = 3.326741e-02
# └ wall time since last report: 5.238 minutes
# ┌ Info: time: 20 days, iter: 9619, Δt: 3 minutes, max|u|: (7.596e-01, 9.964e-01, 2.489e-03) m s⁻¹
# │ T:    min = 2.086305e+00, max = 3.009351e+01 °C
# │ S:    min = 1.607422e+01, max = 3.958218e+01
# │ dye:  min = 5.920604e-144, max = 2.557718e-01
# │ e:    min = 2.105089e-13, max = 6.235991e-04 m² s⁻²
# │ advective CFL = 3.540676e-02
# └ wall time since last report: 5.212 minutes
# ┌ Info: time: 21 days, iter: 10099, Δt: 3 minutes, max|u|: (8.277e-01, 9.549e-01, 3.123e-03) m s⁻¹
# │ T:    min = 2.088867e+00, max = 3.028011e+01 °C
# │ S:    min = 1.602571e+01, max = 3.979937e+01
# │ dye:  min = 4.708634e-142, max = 2.380043e-01
# │ e:    min = 2.352178e-13, max = 5.617657e-04 m² s⁻²
# │ advective CFL = 4.006004e-02
# └ wall time since last report: 5.219 minutes
# ┌ Info: time: 22 days, iter: 10579, Δt: 3 minutes, max|u|: (9.547e-01, 8.227e-01, 3.648e-03) m s⁻¹
# │ T:    min = 2.083079e+00, max = 3.031910e+01 °C
# │ S:    min = 1.583077e+01, max = 4.009636e+01
# │ dye:  min = 7.357265e-140, max = 2.310601e-01
# │ e:    min = 2.684843e-13, max = 7.193031e-04 m² s⁻²
# │ advective CFL = 3.903838e-02
# └ wall time since last report: 5.172 minutes
# ┌ Info: time: 23 days, iter: 11059, Δt: 3 minutes, max|u|: (8.846e-01, 6.557e-01, 6.408e-03) m s⁻¹
# │ T:    min = 2.088054e+00, max = 3.043217e+01 °C
# │ S:    min = 1.577253e+01, max = 4.032661e+01
# │ dye:  min = 2.793474e-132, max = 2.291324e-01
# │ e:    min = 2.359980e-13, max = 7.231440e-04 m² s⁻²
# │ advective CFL = 3.383652e-02
# └ wall time since last report: 5.246 minutes
# ┌ Info: time: 24 days, iter: 11539, Δt: 3 minutes, max|u|: (8.940e-01, 6.590e-01, 7.021e-03) m s⁻¹
# │ T:    min = 2.074833e+00, max = 3.055426e+01 °C
# │ S:    min = 1.578671e+01, max = 4.053734e+01
# │ dye:  min = 1.888250e-129, max = 2.240175e-01
# │ e:    min = 2.489605e-13, max = 8.320557e-04 m² s⁻²
# │ advective CFL = 3.407846e-02
# └ wall time since last report: 5.225 minutes
# ┌ Info: time: 25 days, iter: 12019, Δt: 3 minutes, max|u|: (1.080e+00, 5.993e-01, 7.994e-03) m s⁻¹
# │ T:    min = 2.085743e+00, max = 3.055339e+01 °C
# │ S:    min = 1.570882e+01, max = 4.070911e+01
# │ dye:  min = 1.472016e-127, max = 2.090428e-01
# │ e:    min = 2.028071e-13, max = 6.448191e-04 m² s⁻²
# │ advective CFL = 3.728862e-02
# └ wall time since last report: 5.155 minutes
# ┌ Info: time: 26 days, iter: 12499, Δt: 3 minutes, max|u|: (1.121e+00, 6.294e-01, 8.833e-03) m s⁻¹
# │ T:    min = 2.089135e+00, max = 3.066153e+01 °C
# │ S:    min = 1.548335e+01, max = 4.100509e+01
# │ dye:  min = 1.635431e-125, max = 1.864169e-01
# │ e:    min = 2.546042e-13, max = 7.422610e-04 m² s⁻²
# │ advective CFL = 3.938565e-02
# └ wall time since last report: 5.237 minutes
# ┌ Info: time: 27 days, iter: 12979, Δt: 3 minutes, max|u|: (1.089e+00, 6.158e-01, 5.544e-03) m s⁻¹
# │ T:    min = 2.094295e+00, max = 3.072078e+01 °C
# │ S:    min = 1.535598e+01, max = 4.127913e+01
# │ dye:  min = 2.546066e-123, max = 1.813995e-01
# │ e:    min = 2.233598e-13, max = 1.045961e-03 m² s⁻²
# │ advective CFL = 3.751692e-02
# └ wall time since last report: 5.218 minutes
# ┌ Info: time: 28 days, iter: 13459, Δt: 3 minutes, max|u|: (1.115e+00, 7.227e-01, 6.919e-03) m s⁻¹
# │ T:    min = 2.095294e+00, max = 3.085480e+01 °C
# │ S:    min = 1.512572e+01, max = 4.161918e+01
# │ dye:  min = 2.545936e-119, max = 1.746411e-01
# │ e:    min = 2.273946e-13, max = 1.004216e-03 m² s⁻²
# │ advective CFL = 4.100438e-02
# └ wall time since last report: 5.253 minutes
# ┌ Info: time: 29 days, iter: 13939, Δt: 3 minutes, max|u|: (9.674e-01, 8.633e-01, 6.782e-03) m s⁻¹
# │ T:    min = 2.091403e+00, max = 3.094645e+01 °C
# │ S:    min = 1.492266e+01, max = 4.190136e+01
# │ dye:  min = 1.168771e-115, max = 1.679036e-01
# │ e:    min = 2.488349e-13, max = 9.987087e-04 m² s⁻²
# │ advective CFL = 3.817018e-02
# └ wall time since last report: 5.241 minutes
# ┌ Info: time: 30 days, iter: 14419, Δt: 3 minutes, max|u|: (1.018e+00, 8.178e-01, 1.132e-02) m s⁻¹
# │ T:    min = 2.091593e+00, max = 3.101649e+01 °C
# │ S:    min = 1.495520e+01, max = 4.224246e+01
# │ dye:  min = 6.702784e-114, max = 1.632957e-01
# │ e:    min = 2.400314e-13, max = 8.612683e-04 m² s⁻²
# │ advective CFL = 4.009587e-02
# └ wall time since last report: 5.165 minutes
# ┌ Info: time: 31 days, iter: 14899, Δt: 3 minutes, max|u|: (9.924e-01, 9.415e-01, 9.317e-03) m s⁻¹
# │ T:    min = 2.097808e+00, max = 3.107608e+01 °C
# │ S:    min = 1.525439e+01, max = 4.240842e+01
# │ dye:  min = 1.336465e-112, max = 1.629158e-01
# │ e:    min = 2.724595e-13, max = 6.898831e-04 m² s⁻²
# │ advective CFL = 3.759358e-02
# └ wall time since last report: 5.208 minutes
# ┌ Info: time: 32 days, iter: 15379, Δt: 3 minutes, max|u|: (1.093e+00, 9.302e-01, 6.435e-03) m s⁻¹
# │ T:    min = 2.095039e+00, max = 3.116536e+01 °C
# │ S:    min = 1.519956e+01, max = 4.279630e+01
# │ dye:  min = 4.902704e-110, max = 1.620357e-01
# │ e:    min = 2.791275e-13, max = 7.347180e-04 m² s⁻²
# │ advective CFL = 3.691889e-02
# └ wall time since last report: 5.208 minutes
# ┌ Info: time: 33 days, iter: 15859, Δt: 3 minutes, max|u|: (1.031e+00, 9.622e-01, 5.281e-03) m s⁻¹
# │ T:    min = 2.100457e+00, max = 3.121242e+01 °C
# │ S:    min = 1.490430e+01, max = 4.321222e+01
# │ dye:  min = 1.240403e-109, max = 1.610874e-01
# │ e:    min = 2.102627e-13, max = 6.519748e-04 m² s⁻²
# │ advective CFL = 3.755601e-02
# └ wall time since last report: 5.209 minutes
# ┌ Info: time: 34 days, iter: 16339, Δt: 3 minutes, max|u|: (8.177e-01, 9.432e-01, 4.321e-03) m s⁻¹
# │ T:    min = 2.086065e+00, max = 3.111788e+01 °C
# │ S:    min = 1.457381e+01, max = 4.352652e+01
# │ dye:  min = 1.567113e-106, max = 1.589489e-01
# │ e:    min = 2.616906e-13, max = 7.728767e-04 m² s⁻²
# │ advective CFL = 4.698010e-02
# └ wall time since last report: 5.212 minutes
# ┌ Info: time: 35 days, iter: 16819, Δt: 3 minutes, max|u|: (8.714e-01, 8.473e-01, 4.299e-03) m s⁻¹
# │ T:    min = 2.076731e+00, max = 3.111371e+01 °C
# │ S:    min = 1.481130e+01, max = 4.391582e+01
# │ dye:  min = 2.133100e-104, max = 1.575840e-01
# │ e:    min = 2.567151e-13, max = 7.096093e-04 m² s⁻²
# │ advective CFL = 3.746919e-02
# └ wall time since last report: 5.144 minutes
# ┌ Info: time: 36 days, iter: 17299, Δt: 3 minutes, max|u|: (8.588e-01, 7.675e-01, 3.592e-03) m s⁻¹
# │ T:    min = 2.100919e+00, max = 3.110274e+01 °C
# │ S:    min = 1.486754e+01, max = 4.440760e+01
# │ dye:  min = 7.758774e-103, max = 1.543095e-01
# │ e:    min = 2.303752e-13, max = 5.989973e-04 m² s⁻²
# │ advective CFL = 3.629057e-02
# └ wall time since last report: 5.213 minutes
# ┌ Info: time: 37 days, iter: 17779, Δt: 3 minutes, max|u|: (1.006e+00, 6.479e-01, 3.861e-03) m s⁻¹
# │ T:    min = 2.093708e+00, max = 3.120665e+01 °C
# │ S:    min = 1.424029e+01, max = 4.486313e+01
# │ dye:  min = 6.466918e-101, max = 1.494707e-01
# │ e:    min = 2.316153e-13, max = 6.709216e-04 m² s⁻²
# │ advective CFL = 3.578422e-02
# └ wall time since last report: 5.241 minutes
# ┌ Info: time: 38 days, iter: 18259, Δt: 3 minutes, max|u|: (1.003e+00, 6.023e-01, 3.974e-03) m s⁻¹
# │ T:    min = 2.101478e+00, max = 3.121605e+01 °C
# │ S:    min = 1.407892e+01, max = 4.520557e+01
# │ dye:  min = 2.322465e-99, max = 1.447171e-01
# │ e:    min = 2.521315e-13, max = 7.220237e-04 m² s⁻²
# │ advective CFL = 3.670278e-02
# └ wall time since last report: 5.150 minutes
# ┌ Info: time: 39 days, iter: 18739, Δt: 3 minutes, max|u|: (1.058e+00, 6.297e-01, 4.861e-03) m s⁻¹
# │ T:    min = 2.095361e+00, max = 3.123260e+01 °C
# │ S:    min = 1.395511e+01, max = 4.536016e+01
# │ dye:  min = 1.499071e-98, max = 1.404759e-01
# │ e:    min = 2.634693e-13, max = 6.230433e-04 m² s⁻²
# │ advective CFL = 3.972704e-02
# └ wall time since last report: 5.239 minutes
# ┌ Info: time: 40 days, iter: 19219, Δt: 3 minutes, max|u|: (1.027e+00, 7.717e-01, 8.064e-03) m s⁻¹
# │ T:    min = 2.097336e+00, max = 3.124839e+01 °C
# │ S:    min = 1.375513e+01, max = 4.557081e+01
# │ dye:  min = 5.377908e-98, max = 1.367984e-01
# │ e:    min = 2.953578e-13, max = 6.524444e-04 m² s⁻²
# │ advective CFL = 4.127687e-02
# └ wall time since last report: 5.205 minutes
# ┌ Info: time: 41 days, iter: 19699, Δt: 3 minutes, max|u|: (9.600e-01, 8.485e-01, 5.403e-03) m s⁻¹
# │ T:    min = 2.076613e+00, max = 3.135112e+01 °C
# │ S:    min = 1.350638e+01, max = 4.575300e+01
# │ dye:  min = 2.624710e-94, max = 1.344942e-01
# │ e:    min = 2.887305e-13, max = 5.780781e-04 m² s⁻²
# │ advective CFL = 4.374619e-02
# └ wall time since last report: 5.206 minutes
# ┌ Info: time: 42 days, iter: 20179, Δt: 3 minutes, max|u|: (9.134e-01, 7.809e-01, 5.379e-03) m s⁻¹
# │ T:    min = 2.096617e+00, max = 3.148389e+01 °C
# │ S:    min = 1.319803e+01, max = 4.601945e+01
# │ dye:  min = 2.137040e-92, max = 1.336959e-01
# │ e:    min = 2.791455e-13, max = 5.214271e-04 m² s⁻²
# │ advective CFL = 4.570252e-02
# └ wall time since last report: 5.154 minutes
# ┌ Info: time: 43 days, iter: 20659, Δt: 3 minutes, max|u|: (8.723e-01, 7.720e-01, 3.200e-03) m s⁻¹
# │ T:    min = 2.091239e+00, max = 3.163540e+01 °C
# │ S:    min = 1.289218e+01, max = 4.622815e+01
# │ dye:  min = 1.222058e-89, max = 1.320750e-01
# │ e:    min = 3.119763e-13, max = 3.565889e-04 m² s⁻²
# │ advective CFL = 4.703611e-02
# └ wall time since last report: 5.216 minutes
# ┌ Info: time: 44 days, iter: 21139, Δt: 3 minutes, max|u|: (8.596e-01, 9.074e-01, 2.431e-03) m s⁻¹
# │ T:    min = 2.096137e+00, max = 3.181464e+01 °C
# │ S:    min = 1.267334e+01, max = 4.634500e+01
# │ dye:  min = 7.331933e-88, max = 1.312183e-01
# │ e:    min = 3.094836e-13, max = 5.220275e-04 m² s⁻²
# │ advective CFL = 4.111316e-02
# └ wall time since last report: 5.215 minutes
# ┌ Info: time: 45 days, iter: 21619, Δt: 3 minutes, max|u|: (8.015e-01, 8.197e-01, 4.279e-03) m s⁻¹
# │ T:    min = 2.095335e+00, max = 3.199689e+01 °C
# │ S:    min = 1.253671e+01, max = 4.623274e+01
# │ dye:  min = 6.559204e-86, max = 1.291327e-01
# │ e:    min = 3.126841e-13, max = 5.543376e-04 m² s⁻²
# │ advective CFL = 3.814147e-02
# └ wall time since last report: 5.152 minutes
# ┌ Info: time: 46 days, iter: 22099, Δt: 3 minutes, max|u|: (7.646e-01, 7.112e-01, 3.504e-03) m s⁻¹
# │ T:    min = 2.104473e+00, max = 3.191670e+01 °C
# │ S:    min = 1.252138e+01, max = 4.674051e+01
# │ dye:  min = 2.425435e-85, max = 1.255178e-01
# │ e:    min = 2.999738e-13, max = 5.541272e-04 m² s⁻²
# │ advective CFL = 3.516231e-02
# └ wall time since last report: 5.234 minutes
# ┌ Info: time: 47 days, iter: 22579, Δt: 3 minutes, max|u|: (7.275e-01, 6.611e-01, 4.806e-03) m s⁻¹
# │ T:    min = 2.102237e+00, max = 3.197607e+01 °C
# │ S:    min = 1.232313e+01, max = 4.717234e+01
# │ dye:  min = 6.885316e-85, max = 1.207800e-01
# │ e:    min = 3.233235e-13, max = 6.765490e-04 m² s⁻²
# │ advective CFL = 3.417075e-02
# └ wall time since last report: 5.202 minutes
# ┌ Info: time: 48 days, iter: 23059, Δt: 3 minutes, max|u|: (8.271e-01, 6.940e-01, 2.397e-03) m s⁻¹
# │ T:    min = 2.091382e+00, max = 3.203384e+01 °C
# │ S:    min = 1.213238e+01, max = 4.737203e+01
# │ dye:  min = 7.854971e-83, max = 1.173906e-01
# │ e:    min = 2.601631e-13, max = 6.304770e-04 m² s⁻²
# │ advective CFL = 3.172964e-02
# └ wall time since last report: 5.153 minutes
# ┌ Info: time: 49 days, iter: 23539, Δt: 3 minutes, max|u|: (8.111e-01, 7.705e-01, 3.669e-03) m s⁻¹
# │ T:    min = 2.096317e+00, max = 3.196463e+01 °C
# │ S:    min = 1.200744e+01, max = 4.737549e+01
# │ dye:  min = 8.507657e-82, max = 1.140963e-01
# │ e:    min = 2.522485e-13, max = 6.654213e-04 m² s⁻²
# │ advective CFL = 3.683538e-02
# └ wall time since last report: 5.228 minutes
# ┌ Info: time: 50 days, iter: 24019, Δt: 3 minutes, max|u|: (9.005e-01, 8.737e-01, 4.983e-03) m s⁻¹
# │ T:    min = 2.102689e+00, max = 3.182082e+01 °C
# │ S:    min = 1.187557e+01, max = 4.729054e+01
# │ dye:  min = 1.015609e-79, max = 1.118523e-01
# │ e:    min = 3.082546e-13, max = 6.610647e-04 m² s⁻²
# │ advective CFL = 3.911963e-02
# └ wall time since last report: 5.137 minutes
# ┌ Info: time: 51 days, iter: 24499, Δt: 3 minutes, max|u|: (7.356e-01, 8.259e-01, 2.556e-03) m s⁻¹
# │ T:    min = 2.053318e+00, max = 3.169368e+01 °C
# │ S:    min = 1.182253e+01, max = 4.730521e+01
# │ dye:  min = 2.650172e-77, max = 1.100828e-01
# │ e:    min = 3.051513e-13, max = 8.057677e-04 m² s⁻²
# │ advective CFL = 3.412447e-02
# └ wall time since last report: 5.226 minutes
# ┌ Info: time: 52 days, iter: 24979, Δt: 3 minutes, max|u|: (8.164e-01, 8.734e-01, 2.437e-03) m s⁻¹
# │ T:    min = 2.074324e+00, max = 3.177293e+01 °C
# │ S:    min = 1.177804e+01, max = 4.741540e+01
# │ dye:  min = 8.038997e-76, max = 1.091613e-01
# │ e:    min = 2.487804e-13, max = 6.828536e-04 m² s⁻²
# │ advective CFL = 3.468565e-02
# └ wall time since last report: 5.192 minutes
# ┌ Info: time: 53 days, iter: 25459, Δt: 3 minutes, max|u|: (9.220e-01, 9.262e-01, 2.690e-03) m s⁻¹
# │ T:    min = 2.095958e+00, max = 3.182861e+01 °C
# │ S:    min = 1.172648e+01, max = 4.750053e+01
# │ dye:  min = 2.834287e-75, max = 1.085739e-01
# │ e:    min = 3.138923e-13, max = 6.453453e-04 m² s⁻²
# │ advective CFL = 3.796617e-02
# └ wall time since last report: 5.212 minutes
# ┌ Info: time: 54 days, iter: 25939, Δt: 3 minutes, max|u|: (1.034e+00, 9.047e-01, 4.270e-03) m s⁻¹
# │ T:    min = 2.086822e+00, max = 3.196205e+01 °C
# │ S:    min = 1.152573e+01, max = 4.754147e+01
# │ dye:  min = 1.269281e-73, max = 1.078330e-01
# │ e:    min = 4.018610e-14, max = 7.342607e-04 m² s⁻²
# │ advective CFL = 4.012528e-02
# └ wall time since last report: 5.151 minutes
# ┌ Info: time: 55 days, iter: 26419, Δt: 3 minutes, max|u|: (1.227e+00, 8.910e-01, 4.861e-03) m s⁻¹
# │ T:    min = 2.083864e+00, max = 3.205937e+01 °C
# │ S:    min = 1.144984e+01, max = 4.769721e+01
# │ dye:  min = 4.642552e-72, max = 1.071881e-01
# │ e:    min = 3.533048e-13, max = 7.960678e-04 m² s⁻²
# │ advective CFL = 4.420086e-02
# └ wall time since last report: 5.240 minutes
# ┌ Info: time: 56 days, iter: 26899, Δt: 3 minutes, max|u|: (1.243e+00, 9.096e-01, 5.546e-03) m s⁻¹
# │ T:    min = 2.071646e+00, max = 3.206465e+01 °C
# │ S:    min = 1.141672e+01, max = 4.771673e+01
# │ dye:  min = 4.280573e-71, max = 1.067661e-01
# │ e:    min = 3.278013e-13, max = 9.351230e-04 m² s⁻²
# │ advective CFL = 4.564745e-02
# └ wall time since last report: 5.247 minutes
# ┌ Info: time: 57 days, iter: 27379, Δt: 3 minutes, max|u|: (9.821e-01, 9.514e-01, 4.296e-03) m s⁻¹
# │ T:    min = 2.085643e+00, max = 3.212613e+01 °C
# │ S:    min = 1.126266e+01, max = 4.782920e+01
# │ dye:  min = 8.657353e-71, max = 1.063935e-01
# │ e:    min = 3.049541e-13, max = 9.201607e-04 m² s⁻²
# │ advective CFL = 4.079769e-02
# └ wall time since last report: 5.142 minutes
# ┌ Info: time: 58 days, iter: 27859, Δt: 3 minutes, max|u|: (9.264e-01, 9.333e-01, 4.641e-03) m s⁻¹
# │ T:    min = 2.090913e+00, max = 3.215101e+01 °C
# │ S:    min = 1.109255e+01, max = 4.793739e+01
# │ dye:  min = 1.356356e-69, max = 1.062239e-01
# │ e:    min = 2.955577e-13, max = 8.030652e-04 m² s⁻²
# │ advective CFL = 4.446668e-02
# └ wall time since last report: 5.196 minutes
# ┌ Info: time: 59 days, iter: 28339, Δt: 3 minutes, max|u|: (9.829e-01, 8.168e-01, 6.044e-03) m s⁻¹
# │ T:    min = 2.104349e+00, max = 3.229044e+01 °C
# │ S:    min = 1.097898e+01, max = 4.800209e+01
# │ dye:  min = 2.406727e-69, max = 1.058033e-01
# │ e:    min = 2.931358e-13, max = 8.825336e-04 m² s⁻²
# │ advective CFL = 4.137669e-02
# └ wall time since last report: 5.208 minutes
# ┌ Info: time: 60 days, iter: 28819, Δt: 3 minutes, max|u|: (9.723e-01, 7.327e-01, 4.486e-03) m s⁻¹
# │ T:    min = 2.097487e+00, max = 3.228938e+01 °C
# │ S:    min = 1.061940e+01, max = 4.822709e+01
# │ dye:  min = 9.494563e-69, max = 1.050967e-01
# │ e:    min = 2.898113e-13, max = 7.485385e-04 m² s⁻²
# │ advective CFL = 3.942659e-02
# └ wall time since last report: 5.160 minutes
# ┌ Info: time: 61 days, iter: 29299, Δt: 3 minutes, max|u|: (8.768e-01, 6.879e-01, 4.928e-03) m s⁻¹
# │ T:    min = 2.091957e+00, max = 3.235087e+01 °C
# │ S:    min = 1.030415e+01, max = 4.822827e+01
# │ dye:  min = 2.115494e-68, max = 1.045402e-01
# │ e:    min = 2.948526e-13, max = 7.662472e-04 m² s⁻²
# │ advective CFL = 4.017548e-02
# └ wall time since last report: 5.207 minutes
# ┌ Info: time: 62 days, iter: 29779, Δt: 3 minutes, max|u|: (8.113e-01, 7.017e-01, 7.424e-03) m s⁻¹
# │ T:    min = 2.089872e+00, max = 3.239157e+01 °C
# │ S:    min = 9.887744e+00, max = 4.839204e+01
# │ dye:  min = 4.252828e-67, max = 1.037006e-01
# │ e:    min = 3.168243e-13, max = 8.558167e-04 m² s⁻²
# │ advective CFL = 3.757253e-02
# └ wall time since last report: 5.171 minutes
# ┌ Info: time: 63 days, iter: 30259, Δt: 3 minutes, max|u|: (7.794e-01, 8.557e-01, 9.636e-03) m s⁻¹
# │ T:    min = 2.100754e+00, max = 3.239371e+01 °C
# │ S:    min = 9.481371e+00, max = 4.880046e+01
# │ dye:  min = 6.703792e-66, max = 1.028832e-01
# │ e:    min = 3.609302e-13, max = 8.710297e-04 m² s⁻²
# │ advective CFL = 3.733835e-02
# └ wall time since last report: 5.214 minutes
# ┌ Info: time: 64 days, iter: 30739, Δt: 3 minutes, max|u|: (7.836e-01, 8.863e-01, 5.687e-03) m s⁻¹
# │ T:    min = 2.096818e+00, max = 3.244808e+01 °C
# │ S:    min = 9.113592e+00, max = 4.910486e+01
# │ dye:  min = 4.577873e-65, max = 1.022717e-01
# │ e:    min = 3.239899e-13, max = 8.105061e-04 m² s⁻²
# │ advective CFL = 4.186316e-02
# └ wall time since last report: 5.180 minutes
# ┌ Info: time: 65 days, iter: 31219, Δt: 3 minutes, max|u|: (8.399e-01, 9.231e-01, 5.688e-03) m s⁻¹
# │ T:    min = 2.092055e+00, max = 3.253506e+01 °C
# │ S:    min = 8.744277e+00, max = 4.929813e+01
# │ dye:  min = 7.498308e-64, max = 9.934606e-02
# │ e:    min = 3.088986e-13, max = 6.754124e-04 m² s⁻²
# │ advective CFL = 4.060155e-02
# └ wall time since last report: 5.222 minutes
# ┌ Info: time: 66 days, iter: 31699, Δt: 3 minutes, max|u|: (8.466e-01, 8.498e-01, 4.182e-03) m s⁻¹
# │ T:    min = 2.082431e+00, max = 3.261134e+01 °C
# │ S:    min = 8.396172e+00, max = 4.948269e+01
# │ dye:  min = 4.410087e-62, max = 9.875910e-02
# │ e:    min = 3.046555e-13, max = 7.260483e-04 m² s⁻²
# │ advective CFL = 3.987718e-02
# └ wall time since last report: 5.199 minutes
# ┌ Info: time: 67 days, iter: 32179, Δt: 3 minutes, max|u|: (8.548e-01, 7.000e-01, 4.504e-03) m s⁻¹
# │ T:    min = 2.087992e+00, max = 3.267646e+01 °C
# │ S:    min = 7.984856e+00, max = 4.977144e+01
# │ dye:  min = 3.975987e-60, max = 9.844174e-02
# │ e:    min = 3.850990e-13, max = 8.435156e-04 m² s⁻²
# │ advective CFL = 3.856616e-02
# └ wall time since last report: 5.151 minutes
# ┌ Info: time: 68 days, iter: 32659, Δt: 3 minutes, max|u|: (8.786e-01, 7.643e-01, 3.511e-03) m s⁻¹
# │ T:    min = 2.090077e+00, max = 3.276881e+01 °C
# │ S:    min = 7.672335e+00, max = 5.001214e+01
# │ dye:  min = 3.636542e-59, max = 9.820674e-02
# │ e:    min = 3.376885e-13, max = 7.345912e-04 m² s⁻²
# │ advective CFL = 4.233941e-02
# └ wall time since last report: 5.244 minutes
# ┌ Info: time: 69 days, iter: 33139, Δt: 3 minutes, max|u|: (1.015e+00, 8.051e-01, 2.957e-03) m s⁻¹
# │ T:    min = 2.094046e+00, max = 3.291544e+01 °C
# │ S:    min = 7.331518e+00, max = 5.025216e+01
# │ dye:  min = 3.388162e-58, max = 9.792325e-02
# │ e:    min = 3.457713e-13, max = 6.409460e-04 m² s⁻²
# │ advective CFL = 4.009077e-02
# └ wall time since last report: 5.156 minutes
# ┌ Info: time: 70 days, iter: 33619, Δt: 3 minutes, max|u|: (9.436e-01, 6.896e-01, 3.152e-03) m s⁻¹
# │ T:    min = 2.095834e+00, max = 3.297606e+01 °C
# │ S:    min = 7.039715e+00, max = 5.039184e+01
# │ dye:  min = 1.606420e-57, max = 9.771114e-02
# │ e:    min = 2.698912e-13, max = 5.731518e-04 m² s⁻²
# │ advective CFL = 3.954480e-02
# └ wall time since last report: 5.214 minutes
# ┌ Info: time: 71 days, iter: 34099, Δt: 3 minutes, max|u|: (9.737e-01, 6.798e-01, 7.001e-03) m s⁻¹
# │ T:    min = 2.096972e+00, max = 3.315507e+01 °C
# │ S:    min = 6.839094e+00, max = 5.050460e+01
# │ dye:  min = 4.420134e-57, max = 9.729980e-02
# │ e:    min = 2.684055e-13, max = 5.923710e-04 m² s⁻²
# │ advective CFL = 4.071992e-02
# └ wall time since last report: 5.166 minutes
# ┌ Info: time: 72 days, iter: 34579, Δt: 3 minutes, max|u|: (8.648e-01, 6.543e-01, 7.188e-03) m s⁻¹
# │ T:    min = 2.099774e+00, max = 3.308233e+01 °C
# │ S:    min = 6.570720e+00, max = 5.074940e+01
# │ dye:  min = 7.717913e-57, max = 9.704410e-02
# │ e:    min = 3.936927e-13, max = 8.128709e-04 m² s⁻²
# │ advective CFL = 3.876114e-02
# └ wall time since last report: 5.220 minutes
# ┌ Info: time: 73 days, iter: 35059, Δt: 3 minutes, max|u|: (8.190e-01, 6.548e-01, 6.532e-03) m s⁻¹
# │ T:    min = 2.088666e+00, max = 3.292199e+01 °C
# │ S:    min = 6.271653e+00, max = 5.094976e+01
# │ dye:  min = 4.887769e-56, max = 9.645103e-02
# │ e:    min = 3.841655e-13, max = 6.270048e-04 m² s⁻²
# │ advective CFL = 4.205164e-02
# └ wall time since last report: 5.178 minutes
# ┌ Info: time: 74 days, iter: 35539, Δt: 3 minutes, max|u|: (8.687e-01, 7.385e-01, 4.777e-03) m s⁻¹
# │ T:    min = 2.091520e+00, max = 3.284672e+01 °C
# │ S:    min = 6.165026e+00, max = 5.111110e+01
# │ dye:  min = 5.988160e-54, max = 9.548416e-02
# │ e:    min = 3.282740e-13, max = 6.572011e-04 m² s⁻²
# │ advective CFL = 4.355902e-02
# └ wall time since last report: 5.224 minutes
# ┌ Info: time: 75 days, iter: 36019, Δt: 3 minutes, max|u|: (9.638e-01, 7.741e-01, 3.866e-03) m s⁻¹
# │ T:    min = 2.087894e+00, max = 3.282341e+01 °C
# │ S:    min = 6.132577e+00, max = 5.131419e+01
# │ dye:  min = 9.742212e-53, max = 9.503673e-02
# │ e:    min = 3.667118e-13, max = 6.221087e-04 m² s⁻²
# │ advective CFL = 4.460638e-02
# └ wall time since last report: 5.170 minutes
# ┌ Info: time: 76 days, iter: 36499, Δt: 3 minutes, max|u|: (9.941e-01, 7.276e-01, 4.138e-03) m s⁻¹
# │ T:    min = 2.094136e+00, max = 3.279006e+01 °C
# │ S:    min = 5.838218e+00, max = 5.146645e+01
# │ dye:  min = 1.444176e-52, max = 9.423329e-02
# │ e:    min = 3.525759e-13, max = 5.923561e-04 m² s⁻²
# │ advective CFL = 4.416107e-02
# └ wall time since last report: 5.201 minutes
# ┌ Info: time: 77 days, iter: 36979, Δt: 3 minutes, max|u|: (1.057e+00, 8.007e-01, 4.253e-03) m s⁻¹
# │ T:    min = 2.090983e+00, max = 3.266696e+01 °C
# │ S:    min = 5.036784e+00, max = 5.167239e+01
# │ dye:  min = 1.760398e-52, max = 9.351906e-02
# │ e:    min = 3.488033e-13, max = 5.365209e-04 m² s⁻²
# │ advective CFL = 4.809223e-02
# └ wall time since last report: 5.155 minutes
# ┌ Info: time: 78 days, iter: 37459, Δt: 3 minutes, max|u|: (8.295e-01, 7.650e-01, 2.923e-03) m s⁻¹
# │ T:    min = 2.097562e+00, max = 3.257821e+01 °C
# │ S:    min = 4.404289e+00, max = 5.184677e+01
# │ dye:  min = 5.296592e-52, max = 9.287382e-02
# │ e:    min = 1.123270e-13, max = 5.829854e-04 m² s⁻²
# │ advective CFL = 4.179613e-02
# └ wall time since last report: 5.206 minutes
# ┌ Info: time: 79 days, iter: 37939, Δt: 3 minutes, max|u|: (7.879e-01, 8.335e-01, 3.870e-03) m s⁻¹
# │ T:    min = 2.097999e+00, max = 3.253531e+01 °C
# │ S:    min = 4.026333e+00, max = 5.208782e+01
# │ dye:  min = 1.793421e-51, max = 9.193522e-02
# │ e:    min = 2.716443e-13, max = 7.378615e-04 m² s⁻²
# │ advective CFL = 4.097986e-02
# └ wall time since last report: 5.144 minutes
# [ Info: Simulation is stopping after running for 7.005 hours.
# [ Info: Simulation time 80 days equals or exceeds stop time 80 days.
# ┌ Info: time: 80 days, iter: 38419, Δt: 3 minutes, max|u|: (7.604e-01, 8.976e-01, 4.738e-03) m s⁻¹
# │ T:    min = 2.102084e+00, max = 3.272661e+01 °C
# │ S:    min = 3.612367e+00, max = 5.251711e+01
# │ dye:  min = 4.148565e-50, max = 9.037248e-02
# │ e:    min = 3.622315e-13, max = 5.897720e-04 m² s⁻²
# │ advective CFL = 3.981778e-02
# └ wall time since last report: 5.222 minutes
# ┌ Info: 60-day validation complete
# │   validation_Smin = 3.612367332181683
# │   validation_Smax = 52.51711053044419
# │   validation_CFL = 0.039817783912279796
# └   validation_Δt = 180.0

# %%
# salinity plotting 
using Oceananigans
using CairoMakie
using Printf

salinity_file =
    "amazon_rivers_on_validation_FINAL_nz20_gm_off_redi_off_salinity_80day_v2_salinity_3d.jld2"

# Load salinity lazily from disk.
S_series = FieldTimeSeries(
    salinity_file,
    "S";
    backend = OnDisk()
)

# Analyze the final saved output.
n = length(S_series.times)
final_day = S_series.times[n] / 86400

S_field = S_series[n]
S = Array(interior(S_field))

# Cell-center coordinates.
longitude, latitude, depth =
    nodes(S_series.grid, Center(), Center(), Center())

# Ignore NaNs or masked land cells when locating extrema.
S_for_min = copy(S)
S_for_max = copy(S)

S_for_min[.!isfinite.(S_for_min)] .= Inf
S_for_max[.!isfinite.(S_for_max)] .= -Inf

minimum_index = argmin(S_for_min)
maximum_index = argmax(S_for_max)

imin, jmin, kmin = Tuple(minimum_index)
imax, jmax, kmax = Tuple(maximum_index)

minimum_salinity = S[imin, jmin, kmin]
maximum_salinity = S[imax, jmax, kmax]

minimum_longitude = longitude[imin]
minimum_latitude  = latitude[jmin]
minimum_depth     = depth[kmin]

maximum_longitude = longitude[imax]
maximum_latitude  = latitude[jmax]
maximum_depth     = depth[kmax]

println("Final saved time: ", round(final_day; digits=2), " days")
println()

@printf(
    "Minimum salinity: %.6f PSU\n  longitude: %.4f°\n  latitude:  %.4f°\n  depth:     %.2f m\n  index:     (%d, %d, %d)\n",
    minimum_salinity,
    minimum_longitude,
    minimum_latitude,
    minimum_depth,
    imin,
    jmin,
    kmin
)

println()

@printf(
    "Maximum salinity: %.6f PSU\n  longitude: %.4f°\n  latitude:  %.4f°\n  depth:     %.2f m\n  index:     (%d, %d, %d)\n",
    maximum_salinity,
    maximum_longitude,
    maximum_latitude,
    maximum_depth,
    imax,
    jmax,
    kmax
)

# Plot the horizontal layer containing each extreme.
figure = Figure(size = (1300, 520))

minimum_axis = Axis(
    figure[1, 1];
    title = "Salinity at minimum-depth layer ($(round(minimum_depth; digits=1)) m)",
    xlabel = "Longitude",
    ylabel = "Latitude"
)

minimum_plot = heatmap!(
    minimum_axis,
    longitude,
    latitude,
    S[:, :, kmin];
    colormap = :haline
)

scatter!(
    minimum_axis,
    [minimum_longitude],
    [minimum_latitude];
    color = :red,
    marker = :cross,
    markersize = 22,
    strokewidth = 4
)

Colorbar(
    figure[1, 2],
    minimum_plot;
    label = "Salinity (PSU)"
)

maximum_axis = Axis(
    figure[1, 3];
    title = "Salinity at maximum-depth layer ($(round(maximum_depth; digits=1)) m)",
    xlabel = "Longitude",
    ylabel = "Latitude"
)

maximum_plot = heatmap!(
    maximum_axis,
    longitude,
    latitude,
    S[:, :, kmax];
    colormap = :haline
)

scatter!(
    maximum_axis,
    [maximum_longitude],
    [maximum_latitude];
    color = :magenta,
    marker = :cross,
    markersize = 22,
    strokewidth = 4
)

Colorbar(
    figure[1, 4],
    maximum_plot;
    label = "Salinity (PSU)"
)

figure
# Out:
# [ Info: Precompiling CairoMakie [13f3f980-e62b-5c42-98c6-ff1f3baf88f0](cache misses: wrong dep version loaded (1), mismatched flags (3))
# [ Info: Precompiling CairoMakie [13f3f980-e62b-5c42-98c6-ff1f3baf88f0] (cache misses: wrong dep version loaded (2), mismatched flags (6))
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
# [ Info: Precompiling OceananigansMakieExt [8b7e02c2-18e1-5ade-af7b-cfb5875075c8](cache misses: wrong dep version loaded (1), mismatched flags (3))
# [ Info: Precompiling OceananigansMakieExt [8b7e02c2-18e1-5ade-af7b-cfb5875075c8] (cache misses: wrong dep version loaded (2), mismatched flags (6))
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
# Final saved time: 80.0 days
#
# Minimum salinity: 0.000000 PSU
#   longitude: -58.4750°
#   latitude:  -7.7750°
#   depth:     -3630.70 m
#   index:     (1, 1, 1)
#
# Maximum salinity: 52.517109 PSU
#   longitude: -48.7750°
#   latitude:  -1.3250°
#   depth:     -26.61 m
#   index:     (195, 130, 19)

# %%
# Final and initial saved salinity fields.
S = Array(interior(S_series[n]))
S_initial = Array(interior(S_series[1]))

# Initial ocean salinity is above 0 PSU, while inactive land/bottom
# cells are stored as zero. Use the initial field to construct a fixed
# active-ocean mask.
wet_cell = isfinite.(S_initial) .& (S_initial .> 0)

S_for_min = fill(Inf, size(S))
S_for_max = fill(-Inf, size(S))

S_for_min[wet_cell] .= S[wet_cell]
S_for_max[wet_cell] .= S[wet_cell]

minimum_index = argmin(S_for_min)
maximum_index = argmax(S_for_max)

imin, jmin, kmin = Tuple(minimum_index)
imax, jmax, kmax = Tuple(maximum_index)

minimum_salinity = S[imin, jmin, kmin]
maximum_salinity = S[imax, jmax, kmax]

minimum_longitude = longitude[imin]
minimum_latitude  = latitude[jmin]
minimum_depth     = depth[kmin]

maximum_longitude = longitude[imax]
maximum_latitude  = latitude[jmax]
maximum_depth     = depth[kmax]

println("Final saved time: ", round(final_day; digits=2), " days")
println()

@printf(
    "Minimum active-ocean salinity: %.6f PSU\n  longitude: %.4f°\n  latitude:  %.4f°\n  depth:     %.2f m\n  index:     (%d, %d, %d)\n",
    minimum_salinity,
    minimum_longitude,
    minimum_latitude,
    minimum_depth,
    imin,
    jmin,
    kmin
)

println()

@printf(
    "Maximum active-ocean salinity: %.6f PSU\n  longitude: %.4f°\n  latitude:  %.4f°\n  depth:     %.2f m\n  index:     (%d, %d, %d)\n",
    maximum_salinity,
    maximum_longitude,
    maximum_latitude,
    maximum_depth,
    imax,
    jmax,
    kmax
)

# Use NaN for inactive cells so land appears blank in the plots.
S_plot = Float64.(S)
S_plot[.!wet_cell] .= NaN

figure = Figure(size = (1300, 520))

minimum_axis = Axis(
    figure[1, 1];
    title = "Active-ocean minimum layer ($(round(minimum_depth; digits=1)) m)",
    xlabel = "Longitude",
    ylabel = "Latitude"
)

minimum_plot = heatmap!(
    minimum_axis,
    longitude,
    latitude,
    S_plot[:, :, kmin];
    colormap = :haline
)

scatter!(
    minimum_axis,
    [minimum_longitude],
    [minimum_latitude];
    color = :red,
    marker = :cross,
    markersize = 22,
    strokewidth = 4
)

Colorbar(figure[1, 2], minimum_plot; label = "Salinity (PSU)")

maximum_axis = Axis(
    figure[1, 3];
    title = "Active-ocean maximum layer ($(round(maximum_depth; digits=1)) m)",
    xlabel = "Longitude",
    ylabel = "Latitude"
)

maximum_plot = heatmap!(
    maximum_axis,
    longitude,
    latitude,
    S_plot[:, :, kmax];
    colormap = :haline
)

scatter!(
    maximum_axis,
    [maximum_longitude],
    [maximum_latitude];
    color = :magenta,
    marker = :cross,
    markersize = 22,
    strokewidth = 4
)

Colorbar(figure[1, 4], maximum_plot; label = "Salinity (PSU)")

figure
